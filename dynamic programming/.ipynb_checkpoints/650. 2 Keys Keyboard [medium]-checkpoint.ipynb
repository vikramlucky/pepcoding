# %% [markdown]
# ![Screen%20Shot%202021-04-26%20at%202.58.40%20PM.png](attachment:Screen%20Shot%202021-04-26%20at%202.58.40%20PM.png)

# %%
def minSteps(n):
    prev = [i for i in range(n+1)]
    prev[1] = 0

    for i in range(3, n + 1):

        prev[i] = i

        j = i // 2

        for j in range(j, 0, -1):
            if i % j == 0:
                prev[i] = prev[j] + i //j
                break
    return prev[n]
